# %%
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline
import seaborn as sb

# %%
pokemon_df = pd.read_csv('pokemon.csv')
pokemon_df.head()
# Out:
#    id     species  generation_id  height  weight  base_experience type_1  \
# 0   1   bulbasaur              1     0.7     6.9               64  grass
# 1   2     ivysaur              1     1.0    13.0              142  grass
# 2   3    venusaur              1     2.0   100.0              236  grass
# 3   4  charmander              1     0.6     8.5               62   fire
# 4   5  charmeleon              1     1.1    19.0              142   fire
#
#    type_2  hp  attack  defense  speed  special-attack  special-defense
# 0  poison  45      49       49     45              65               65
# 1  poison  60      62       63     60              80               80
# 2  poison  80      82       83     80             100              100
# 3     NaN  39      52       43     65              60               50
# 4     NaN  58      64       58     80              80               65

# %% [markdown]
# # Visualizing quantitative vs quantitative
# pokemon height vs weight. Both are continuous quantitative variables

# %%
plt.scatter(x = pokemon_df.height,y = pokemon_df.weight);

# %% [markdown]
# ### Seaborn regplot

# %%
sb.regplot(x='height',y='weight' ,data = pokemon_df, scatter_kws = {'alpha':1/6} );
# Out:
# C:\Users\Ashok Anand\AppData\Roaming\Python\Python37\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Attack vs defense

# %%
sb.regplot(x = 'attack', y = 'defense', data = pokemon_df,x_jitter = 0.2,y_jitter = 0.2, scatter_kws = {'alpha':1/6})
# Out:
# C:\Users\Ashok Anand\AppData\Roaming\Python\Python37\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Special attack vs defense

# %%
sb.regplot(x = 'special-attack', y = 'special-defense', data = pokemon_df, scatter_kws = {'alpha':1/6})
# Out:
# C:\Users\Ashok Anand\AppData\Roaming\Python\Python37\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Heatmaps
# Lets use the automobile dataset

# %%
car_df = pd.read_csv('fuel-econ.csv')
car_df.head()
# Out:
#       id        make           model  year           VClass  \
# 0  32204      Nissan            GT-R  2013  Subcompact Cars
# 1  32205  Volkswagen              CC  2013     Compact Cars
# 2  32206  Volkswagen              CC  2013     Compact Cars
# 3  32207  Volkswagen      CC 4motion  2013     Compact Cars
# 4  32208   Chevrolet  Malibu eAssist  2013     Midsize Cars
#
#                drive              trans          fuelType  cylinders  displ  \
# 0    All-Wheel Drive    Automatic (AM6)  Premium Gasoline          6    3.8
# 1  Front-Wheel Drive  Automatic (AM-S6)  Premium Gasoline          4    2.0
# 2  Front-Wheel Drive     Automatic (S6)  Premium Gasoline          6    3.6
# 3    All-Wheel Drive     Automatic (S6)  Premium Gasoline          6    3.6
# 4  Front-Wheel Drive     Automatic (S6)  Regular Gasoline          4    2.4
#
#    pv2  pv4     city    UCity  highway  UHighway     comb  co2  feScore  \
# ...

# %% [markdown]
# #### Comparing cylinders vs fescore
# using scatter plot first (seaborn)

# %%
sb.regplot(x = 'cylinders',y = 'feScore',data = car_df);
# Out:
# C:\Users\Ashok Anand\AppData\Roaming\Python\Python37\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Here we do not see how many cars are sampled in each feScore and cylinder pair.
#
# Adding jitter for x and y, and reducing the opacity we get a more insightful plot

# %%
sb.regplot(x = 'cylinders',y = 'feScore',data = car_df,x_jitter = 0.35,y_jitter = 0.35,scatter_kws = {'alpha':1/20});
# Out:
# C:\Users\Ashok Anand\AppData\Roaming\Python\Python37\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Heatmap
# - figsize argument to set plot area size
# - bins_x and y - set with np.arange function. [min, max, stepsize]
#
# ### hist2d
# - **cmin** - set minimum value to be coloured
# - **bins** - takes a tuple of bin edges
# - **cmap** - color map type. Here viridis_r. _r represents inverting the color map. **More colour maps are in the matplotlib documentation**

# %%
import numpy as np

fig = plt.figure(figsize=(8,5)) # setting appropriate figsize

bins_x = np.arange(0,13,1) # setting bin edges for x and y. does not matter here though
bins_y = np.arange(0,11,1)

plt.hist2d(data = car_df, x='cylinders',y='feScore',cmin=1,
          cmap = 'viridis_r',bins = (bins_x,bins_y))
sb.regplot(data = car_df, x='cylinders',y = 'feScore',scatter=False)

plt.colorbar()
plt.xlabel('Cylinders')
plt.ylabel('FE Score');
# Out:
# C:\Users\Ashok Anand\AppData\Roaming\Python\Python37\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
car_df[['cylinders','feScore']].describe()
# Out:
#          cylinders      feScore
# count  3929.000000  3929.000000
# mean      5.468313     5.668872
# std       1.878319     1.755860
# min       2.000000     1.000000
# 25%       4.000000     5.000000
# 50%       5.000000     5.000000
# 75%       6.000000     7.000000
# max      12.000000    10.000000

# %% [markdown]
# ### Use subplots to show heatmap and scatter side by side
# Show the cylinders vs FeScore comparison

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sb.regplot(data = car_df,x='cylinders',y='feScore',x_jitter=0.4,y_jitter=0.4,scatter_kws={'alpha':0.02})

plt.subplot(1,2,2)
plt.hist2d(data = car_df,x='cylinders',y='feScore',cmap='viridis_r',cmin=1)
plt.colorbar();
# Out:
# C:\Users\Ashok Anand\AppData\Roaming\Python\Python37\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Adjusting the second figure's size
# - best method is to store axes outputs from plt.subplots() and set gridspec_kw - width_ratios
#
# > Use plt.sca() to set Current axis parameter. Later plt methods work on this current axes that is set to current such as xlabel and ylabel

# %%
f, (a0, a1) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [ 1,1.3]},figsize=(13,5))
sb.regplot(data = car_df,x='cylinders',y='feScore',x_jitter=0.4,y_jitter=0.4,scatter_kws={'alpha':0.02},ax=a0)
plt.sca(a0)
plt.xlabel('Cylinders')
plt.ylabel('FE Score')

plt.sca(a1)
plt.xlabel('Cylinders')
plt.ylabel('FE Score')
p = a1.hist2d(data = car_df,x='cylinders',y='feScore',cmap='viridis_r',cmin=1);
plt.colorbar(p[3]);
# Out:
# C:\Users\Ashok Anand\AppData\Roaming\Python\Python37\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Bivariate viz - Categorical vs quantitative (Violin plots)
# Use the seaborn.violinplot to plot this type of viz

# %%
car_df.head(2)
# Out:
#       id        make model  year           VClass              drive  \
# 0  32204      Nissan  GT-R  2013  Subcompact Cars    All-Wheel Drive
# 1  32205  Volkswagen    CC  2013     Compact Cars  Front-Wheel Drive
#
#                trans          fuelType  cylinders  displ  pv2  pv4     city  \
# 0    Automatic (AM6)  Premium Gasoline          6    3.8   79    0  16.4596
# 1  Automatic (AM-S6)  Premium Gasoline          4    2.0   94    0  21.8706
#
#      UCity  highway  UHighway     comb  co2  feScore  ghgScore
# 0  20.2988  22.5568   30.1798  18.7389  471        4         4
# 1  26.9770  31.0367   42.4936  25.2227  349        6         6

# %% [markdown]
# #### Checking how combined fuel efficiency varies with fuel type

# %%
f = plt.figure(figsize=(12,5))
sb.violinplot(data = car_df, x='fuelType',y='comb',inner=None);
plt.xticks(rotation=0)
plt.ylabel('Combined Fuel Efficiency')
plt.xlabel('Fuel Type')
# Out:
# Text(0.5,0,'Fuel Type')

# %% [markdown]
# ## Violin plots observations and syntax
# - 'inner = None' argument removes the inner box plot which is plotted by default
# - violin plots are good for when there are less categories in the categorical, and there are less or no outliers in the quantitative variable

# %%
base_color = sb.color_palette()[1]
f = plt.figure(figsize=(12,5))
sb.violinplot(data = car_df, x='fuelType',y='comb',inner='quartile',color = base_color);
plt.xticks(rotation=0)
plt.ylabel('Combined Fuel Efficiency')
plt.xlabel('Fuel Type')
# Out:
# Text(0.5,0,'Fuel Type')

# %% [markdown]
# ## Box plot
# Same syntax as the violin plot. does not take the inner argument
#
# >box plots are good for qualitative vs quantitative, and it is good for handling outliers as well.

# %%
base_color = sb.color_palette()[0]
f = plt.figure(figsize=(12,5))
sb.boxplot(data = car_df, x='fuelType',y='comb',color = base_color);
plt.xticks(rotation=0)
plt.ylabel('Combined Fuel Efficiency')
plt.xlabel('Fuel Type')
# Out:
# Text(0.5,0,'Fuel Type')

# %% [markdown]
# # Categorical vs Categorical
# Clustered bar chart is one option

# %%
car_df.head(1)
# Out:
#       id    make model  year           VClass            drive  \
# 0  32204  Nissan  GT-R  2013  Subcompact Cars  All-Wheel Drive
#
#              trans          fuelType  cylinders  displ  pv2  pv4     city  \
# 0  Automatic (AM6)  Premium Gasoline          6    3.8   79    0  16.4596
#
#      UCity  highway  UHighway     comb  co2  feScore  ghgScore
# 0  20.2988  22.5568   30.1798  18.7389  471        4         4

# %%
# extracting transmission type from trans variable
car_df['transType'] = car_df.trans.apply(lambda x: x.split()[0])

# %%
sb.countplot(data = car_df, x='VClass',hue = 'transType')
plt.xticks(rotation=20);

# %% [markdown]
# ## Comparing clustered bar chart with heatmap for same data
# Seaborn's heatmap function works for categorical vs categorical.
#
# But the nuance is that a pre calculated matrix needs to be supplied for plotting the heatmap

# %%
c = car_df
c = c.groupby(['VClass','transType']).size().unstack('VClass')

f, (a0,a1) = plt.subplots(1,2,figsize = (14,5))
plt.sca(a0)
p = sb.heatmap(c, annot=True,fmt='d',ax = a0)
plt.xticks(rotation=20)
plt.sca(a1)
sb.countplot(data = car_df, x='VClass',hue = 'transType',order=c.columns)
plt.xticks(rotation=20);

# %% [markdown]
# # Facetting
# Bivariate or multivariate visualizations can be done by facetting plots by a variable. Facetting means plotting disjoint subsets of data based on a variable.
#
# For example, for each level in a categorical variable, a histogram of a quantitative variable can be plotted. Hence there would be histogram plots equal to the number of levels in the categorical variable.
#
# ### Facetting FE score by vehicle class

# %%
g = sb.FacetGrid(data = car_df, col = 'VClass',col_wrap=3)
g.map(plt.hist,'feScore');

# %% [markdown]
# ### Facetting CO2 emmisions by vehicle class

# %%
g = sb.FacetGrid(data = car_df, col = 'VClass',col_wrap=3)
g.map(sb.distplot,'co2');
# Out:
# C:\Users\Ashok Anand\AppData\Roaming\Python\Python37\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Using Univariate visualization methods for bivariate analysis
# #### Bar chart instead of showing count, shows mean of another quantitative variable
# Vehicle class to fuel

# %%
c = car_df[car_df.drive.isin(car_df.drive.value_counts().index[:-2])].groupby('drive').displ.mean()
c
# Out:
# drive
# 4-Wheel Drive        3.499561
# All-Wheel Drive      3.100219
# Front-Wheel Drive    2.040450
# Rear-Wheel Drive     3.870516
# Name: displ, dtype: float64

# %%
plt.bar(x=c.index,height=c)
plt.ylabel('Displacement (cc)')
plt.xlabel('Drive Type')
plt.xticks(rotation=20)
# Out:
# ([0, 1, 2, 3], <a list of 4 Text xticklabel objects>)
